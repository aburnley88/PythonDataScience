# %% [markdown]
# ## Data Visualization with Matplotlib

# %% [markdown]
# get all required packages

# %%
# allows for inline use of matplotlib
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### plt.plot()

# %% [markdown]
# **Signature:** plt.plot(*args, scalex=True, scaley=True, data=None, kwargs)\
# **Docstring:**
# Plot y versus x as lines and/or markers.

# %%
# this is an empty plot, or basic figure
plt.plot()
# Out:
# []

# %%
# to remove the brackets from the output use a ';' or plt.show()

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
# create plot with x-axis values 
plt.plot([1,2,3,4])
plt.show()

# %%
# this form of plotting is stateless plotting
x = [1,2,3,4]
y = [11, 22, 33, 44]
plt.plot(x,y);

# %%
# it is more acceptable to use an object oriented style of plotting
# 1st method

fig = plt.figure() # creates a figure
ax = fig.add_subplot() #adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, .5])
ax.plot(x,y) #plot the data
plt.show() # show visual

# %% [markdown]
# Note : To understand multiple axes( multiple rectangle insertion in generated figure) easily, Think of  a rectangle which is 1 * 1 (with 0.1 as increment ).Within the rectangle we have arrange those axes with specifying ([a,b,c,d])
#
# (a,b) is the point in southwest corner of the rectangle which we create. c represents width and d represents height of the respective rectangle.

# %%
# 3rd (recommended)
fig, ax = plt.subplots()
ax.plot(x,y);

# %% [markdown]
# **Docstring:**
# Create a figure and a set of subplots.
#
# This utility wrapper makes it convenient to create common layouts of
# subplots, including the enclosing figure object, in a single call.
#
#
# **Parameters:** \
# nrows, ncols : int, default: 1
#     Number of rows/columns of the subplot grid.
#
# sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#     Controls sharing of properties among x (*sharex*) or y (*sharey*)
#     axes:
#
#     - True or 'all': x- or y-axis will be shared among all subplots.
#     - False or 'none': each subplot x- or y-axis will be independent.
#     - 'row': each subplot row will share an x- or y-axis.
#     - 'col': each subplot column will share an x- or y-axis.
#
#     When subplots have a shared x-axis along a column, only the x tick
#     labels of the bottom subplot are created. Similarly, when subplots
#     have a shared y-axis along a row, only the y tick labels of the first
#     column subplot are created. To later turn other subplots' ticklabels
#     on, use `~matplotlib.axes.Axes.tick_params`.
#
#     When subplots have a shared axis that has units, calling
#     `~matplotlib.axis.Axis.set_units` will update each axis with the
#     new units.
#
# squeeze : bool, default: True
#     - If True, extra dimensions are squeezed out from the returned
#       array of `~matplotlib.axes.Axes`:
#
#       - if only one subplot is constructed (nrows=ncols=1), the
#         resulting single Axes object is returned as a scalar.
#       - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#         object array of Axes objects.
#       - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#
#     - If False, no squeezing at all is done: the returned Axes object is
#       always a 2D array containing Axes instances, even if it ends up
#       being 1x1.
#
# width_ratios : array-like of length *ncols*, optional
#     Defines the relative widths of the columns. Each column gets a
#     relative width of ``width_ratios[i] / sum(width_ratios)``.
#     If not given, all columns will have the same width.  Equivalent
#     to ``gridspec_kw={'width_ratios': [...]}``.
#
# height_ratios : array-like of length *nrows*, optional
#     Defines the relative heights of the rows. Each row gets a
#     relative height of ``height_ratios[i] / sum(height_ratios)``.
#     If not given, all rows will have the same height. Convenience
#     for ``gridspec_kw={'height_ratios': [...]}``.
#
# subplot_kw : dict, optional
#     Dict with keywords passed to the
#     `~matplotlib.figure.Figure.add_subplot` call used to create each
#     subplot.
#
# gridspec_kw : dict, optional
#     Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#     constructor used to create the grid the subplots are placed on.
#
# **fig_kw**
#     All additional keyword arguments are passed to the
#     `.pyplot.figure` call.

# %% [markdown]
# <img src="matplotlib_imgs/matplotlib-anatomy-of-a-plot.png"/>

# %% [markdown]
# <img src="matplotlib_imgs/matplotlib-anatomy-of-a-plot-with-code.png" />

# %% [markdown]
# ## Matplotlib Example Workflow

# %%
# 1. prepare data 

ex = [2.5, 7, 8, 3, 2.8]
whys = [15, 17.5, 24, 29, 32]

# 2. setup plot
fig, ax = plt.subplots(figsize = (8,8))

# 3. plot data
ax.plot(whys, ex);

# 4. customize plot
ax.set(title="Simple Plots",
       xlabel="Age When I met her",
       ylabel="Length of Relationship (years)")

# 5. save the plot
fig.savefig("matplotlib_imgs/sample_plot.png")

# %% [markdown]
# ## Making figures with numpy arrays

# %%
x = np.linspace(0, 10, 100)
fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x, x*3);

# %%
x[:3]
# Out:
# array([0.       , 0.1010101, 0.2020202])

# %% [markdown]
# ### scatter plot

# %%
yy = np.random.uniform(size=100)

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x, yy)
ax.plot;

# %% [markdown]
# ### bar chart

# %%
fig, ax = plt.subplots(figsize=(10,10))
jobs = {"Jr. Application Developer": 6,
        ".Net Developer": 15,
        "U.S. Airman": 72}
ax.bar(jobs.keys(), jobs.values());
ax.set(title="Simple Plots",
       xlabel="Job",
       ylabel="Time in position (months)")
# Out:
# [Text(0.5, 1.0, 'Simple Plots'),
#  Text(0.5, 0, 'Job'),
#  Text(0, 0.5, 'Time in position (months)')]

# %% [markdown]
# ### Histogram

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots(figsize=(5,5))
ax.hist(x);

# %% [markdown]
# ### two options for subplots

# %%
## option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10,5))
# plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.barh(list(jobs.keys()), list(jobs.values()));
ax4.hist(x);

# %%
# subplot option 2

# %%
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10,5))
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].barh(list(jobs.keys()), list(jobs.values()));
ax[1, 1].hist(x);

# %% [markdown]
# ### Visualizing Data with Pandas

# %%
car_sales = pd.read_csv("numpy-images/car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# taken from documentation

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2023", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales["Date of Sale"] = pd.date_range("1/1/2022", periods= len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Date of Sale
# 0  Toyota  White         150043      4   $4,000.00   2022-01-01
# 1   Honda    Red          87899      4   $5,000.00   2022-01-02
# 2  Toyota   Blue          32549      3   $7,000.00   2022-01-03
# 3     BMW  Black          11179      5  $22,000.00   2022-01-04
# 4  Nissan  White         213095      4   $3,500.00   2022-01-05
# 5  Toyota  Green          99213      4   $4,500.00   2022-01-06
# 6   Honda   Blue          45698      4   $7,500.00   2022-01-07
# 7   Honda   Blue          54738      4   $7,000.00   2022-01-08
# 8  Toyota  White          60000      4   $6,250.00   2022-01-09
# 9  Nissan  White          31600      4   $9,700.00   2022-01-10

# %%
# convert price column to float
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\,]', "", regex=True).astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Date of Sale
# 0  Toyota  White         150043      4   4000.0   2022-01-01
# 1   Honda    Red          87899      4   5000.0   2022-01-02
# 2  Toyota   Blue          32549      3   7000.0   2022-01-03
# 3     BMW  Black          11179      5  22000.0   2022-01-04
# 4  Nissan  White         213095      4   3500.0   2022-01-05
# 5  Toyota  Green          99213      4   4500.0   2022-01-06
# 6   Honda   Blue          45698      4   7500.0   2022-01-07
# 7   Honda   Blue          54738      4   7000.0   2022-01-08
# 8  Toyota  White          60000      4   6250.0   2022-01-09
# 9  Nissan  White          31600      4   9700.0   2022-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Date of Sale  Total Sales
# 0  Toyota  White         150043      4   4000.0   2022-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0   2022-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0   2022-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0   2022-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0   2022-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0   2022-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0   2022-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0   2022-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0   2022-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0   2022-01-10      76450.0

# %%
# line plot

# %%
car_sales.plot(x="Date of Sale", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
heart_disease = pd.read_csv("numpy-images/heart-disease.csv")

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a histogram of age column
heart_disease["age"].plot.hist();

# %%
# change the num of bins
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %%
heart_disease.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_disease.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1

# %%
fifty_pls = heart_disease[heart_disease["age"]>50]

# %%
fifty_pls.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean    59.375000    0.668269    0.918269  134.802885  252.846154    0.187500
# std      5.603118    0.471971    1.062334   18.541104   54.382572    0.391254
# min     51.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     55.000000    0.000000    0.000000  121.500000  215.500000    0.000000
# 50%     58.500000    1.000000    0.000000  132.000000  246.000000    0.000000
# 75%     63.000000    1.000000    2.000000  145.000000  283.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.490385  144.552885    0.375000    1.210096    1.341346    0.889423
# ...

# %%
fifty_pls.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method
fifty_pls.plot.scatter('age','chol',c='target');

# %%
fig, ax = plt.subplots(figsize=(10,6))
fifty_pls.plot(kind='scatter', x='age', y='chol', c='target', ax=ax );
ax.set_xlim([50, 77]);

# %%
## object oriented
fig, ax = plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(fifty_pls['age'], fifty_pls['chol'], c=fifty_pls['target'])

#customize
ax.set(title="Heart Disease Relative to Cholesterol Level",
       xlabel="Age (years)",
       ylabel="Cholesterol (mg/dl)")

# add a legend
ax.legend(*scatter.legend_elements(), title ="Target(1=pos, 0=neg)");

# add a horizaontal line
ax.axhline(fifty_pls["chol"].mean(),
         linestyle='--');

# %%
fifty_pls.rename(columns={'thalach':'Max Heart Rate'}, inplace=True)
# Out:
# C:\Users\aburn\AppData\Local\Temp\ipykernel_13624\364056743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fifty_pls.rename(columns={'thalach':'Max Heart Rate'}, inplace=True)

# %%
fifty_pls.head(1)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  Max Heart Rate  exang  oldpeak  \
# 0   63    1   3       145   233    1        0             150      0      2.3
#
#    slope  ca  thal  target
# 0      0   0     1       1

# %%
## object oriented
fig, ax = plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(fifty_pls['age'], fifty_pls['Max Heart Rate'], c=fifty_pls['target'])

#customize
ax.set(title="Heart Disease Relative to Heart Rate",
       xlabel="Age (years)",
       ylabel="Heart Rate (bpm)")

# add a legend
ax.legend(*scatter.legend_elements(), title ="Target(1=pos, 0=neg)");

# add a horizaontal line
ax.axhline(fifty_pls["Max Heart Rate"].mean(),
         linestyle='--');

# %%
# put the charts together in subplot

fig, ((ax1),(ax2)) = plt.subplots(nrows=2,
                       ncols=1,
                       figsize=(10,10))

scatter_one = ax1.scatter(fifty_pls['age'], fifty_pls['Max Heart Rate'], c=fifty_pls['target'])
scatter_two = ax2.scatter(fifty_pls['age'], fifty_pls['chol'], c=fifty_pls['target'])

ax1.set(title="Heart Disease Relative to Heart Rate",
       xlabel="Age (years)",
       ylabel="Heart Rate (bpm)")
ax2.set(title="Heart Disease Relative to Cholesterol Level",
       xlabel="Age (years)",
       ylabel="Cholesterol (mg/dl)")

ax1.legend(*scatter.legend_elements(), title ="Target(1=pos, 0=neg)");
ax2.legend(*scatter_two.legend_elements(), title ="Target(1=pos, 0=neg)");


ax1.axhline(fifty_pls["Max Heart Rate"].mean(),
         linestyle='--');
ax2.axhline(fifty_pls["chol"].mean(),
         linestyle='--');

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
# ### Customizing Matplotlib and using Style

# %%
# see what styles are available

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# see default

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8-whitegrid')
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8')
car_sales["Price"].plot();

# %%
plt.style.use('dark_background')
car_sales["Price"].plot();

# %%
# create some data

df= pd.DataFrame(np.random.randn(11, 4), columns=['A', 'B', 'C', 'D'])
df.head()
# Out:
#           A         B         C         D
# 0 -1.213135 -1.622668  0.366129  0.500746
# 1 -0.699625  0.490730 -1.817449 -0.058899
# 2  2.121478  1.003573  0.621896 -1.074171
# 3  0.691853  2.211434  0.252262 -1.677884
# 4  1.224290  1.322453  1.418565  0.677899

# %%
plt.style.use('seaborn-v0_8')
ax = df.plot.bar()
ax.set(title="Random Bar Graph", 
       xlabel="randx", 
       ylabel="randY");

ax.legend().set_visible(False)

# %%
plt.style.use('seaborn-v0_8-whitegrid')

## object oriented
fig, ax = plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(fifty_pls['age'], fifty_pls['Max Heart Rate'], c=fifty_pls['target'], cmap="summer")

#customize
ax.set(title="Heart Disease Relative to Heart Rate",
       xlabel="Age (years)",
       ylabel="Heart Rate (bpm)")

# add a legend
ax.legend(*scatter.legend_elements(), title ="Target(1=pos, 0=neg)");

# add a horizaontal line
ax.axhline(fifty_pls["Max Heart Rate"].mean(),
         linestyle='--', c="red");
